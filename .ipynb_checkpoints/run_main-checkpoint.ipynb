# %%
# %load_ext autoreload
# %autoreload 2

# %%
exec(open("tab_builder.py").read())
# Out:
# Enter tab type (S for simple tab, L for L-bracket,c to check connection): S
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=532x496 at 0x22BC688C4F0>
# length:1
# bore_size:0.5
# bore_placement:1.5
# width:0.1
# height:2
# notched_radius:1.25
# m to modify dimension, q to quit, or s to save: m
# enter new dimension equation from this list[height, bore size, bore placement, width,arc rad, L bracket length]: width = 0.25
# m to modify dimension, q to quit, or s to save: q
