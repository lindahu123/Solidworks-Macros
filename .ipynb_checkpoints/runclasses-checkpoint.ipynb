# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
exec(open("test.py").read())
# Out:
# Enter tab type (S for simple tab, L for L-bracket, c to check connection): S
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=737x725 at 0x25A6849B5B0>
# length:1
# bore_size:0.25
# bore_placement:1
# width:0.1
# notched_radius:1.25
# Dimension to change, q to quit, or s to saves

# %%
i = 0
dict1 = {}
while eqMgr.Equation(i) != '':
    dict1[eqMgr.Equation(i)] = i
    i +=1

# %%
print(dict1)
# Out:
# {'"length" = 0.025399986284007407': 0, '"width" = 0.0025399986284007406': 1, '"bore size" = 0.012699993142003704': 2, '"bore placement" = 0.025399986284007407': 3, '"arc rad" = 0.03174998285500926': 4, '"L bracket length"= 0': 5, '"D1@Sketch1" =  "length"': 6, '"D3@Sketch1" =  "bore placement"': 7, '"D5@Sketch1" =  "bore size"': 8, '"D4@Sketch1" =  "length"/2': 9}

# %%
for i in dict1:
    if "length" in i:
        if "@" in i:
            print(i)
# Out:
# "D1@Sketch1" =  "length"
# "D4@Sketch1" =  "length"/2
